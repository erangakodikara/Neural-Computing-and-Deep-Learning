# %% [markdown]
# <html> <h1 style="font-style:bold; color:blue;"> Neural Computing and Deep Learning </h1> </html>

# %% [markdown]
# <html> <h1 style="font-style:italic; color:blue;"> Week-10 </h1> </html>

# %% [markdown]
# <html> <h2 style="font-style:italic; color:blue;"> Simple AutoEncoders with Image Data </h2> </html>
#
# Here is a simple autoencoder with just the dense layers.

# %% [markdown]
# Load the data and import the libraries.

# %%
# Your code to import matplotlib, pandas and numpy libraries

#
#
#

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# _______________________![image.png](attachment:a4e07154-e766-4e74-a203-c09e7605ea7b.png)

# %%
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# __________________![image.png](attachment:06d151d2-f461-411d-8325-a4a6287cfd48.png)

# %%
print(tf.__version__)
# Out:
# 2.19.0

# %% [markdown]
# ____________________![image.png](attachment:3ff556fc-1f76-4be4-a216-1e8aecd11e54.png)

# %%
from keras.layers import Dense, Input

from keras.models import Model

from keras.datasets import mnist

# %%
# Your code to load MNIST data and store it in variables x_train, x_test.
# Note -  we do not need labels as it's autoencoder.

#

# %%
import numpy as np

(x_train, _), (x_test, _) = mnist.load_data()

# %% [markdown]
# ______________________![image.png](attachment:74823cdf-09eb-4a7a-8a39-8c306d6de031.png)

# %%
n =10
plt.figure(figsize=(20, 4))
for i in range(n):
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
# Your code to
# normalise train data - Divided by 255

#

# normalise test data - Divided by 255

x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# %% [markdown]
# <html> <h3 style="font-style:italic; color:blue;"> Basic AutoEncoder : </h3> </html>
#
# Build a basic symmetric encoder-decoder network that recreates the image.
# This network could be used in dimensionaliry reduction or feature learning.

# %% [markdown]
# ________________________![image.png](attachment:de80ae8e-d8d5-4cfc-a51b-a2f7d50dc7c2.png)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Reshape
from tensorflow.keras.optimizers import SGD

# %%
encoder = Sequential()
encoder.add(Flatten(input_shape=[28,28]))
encoder.add(Dense(50, activation='relu'))
encoder.add(Dense(25, activation='relu'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Your code to print your Encoder model
print(encoder.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 50)             │        39,250 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 25)             │         1,275 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 40,525 (158.30 KB)
#  Trainable params: 40,525 (158.30 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
decoder = Sequential()
decoder.add(Dense(25, input_shape=[25], activation='relu'))
decoder.add(Dense(50, activation='relu'))
decoder.add(Dense(28 * 28, activation="sigmoid"))
decoder.add(Reshape([28, 28]))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Your code to print the Decoder model

#

# %%
print(decoder.summary())
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 25)             │           650 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 50)             │         1,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 784)            │        39,984 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 28, 28)         │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 41,934 (163.80 KB)
#  Trainable params: 41,934 (163.80 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# ____________________![image.png](attachment:a94c2e5b-e27d-4e12-84c9-116a2f70e393.png)

# %%
autoencoder = Sequential([encoder, decoder])
print(autoencoder.summary())
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (None, 25)             │        40,525 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_1 (Sequential)       │ (None, 28, 28)         │        41,934 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 82,459 (322.11 KB)
#  Trainable params: 82,459 (322.11 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
print(autoencoder.summary())
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (None, 25)             │        40,525 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_1 (Sequential)       │ (None, 28, 28)         │        41,934 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 82,459 (322.11 KB)
#  Trainable params: 82,459 (322.11 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
#SGD?

# %%
# Your code to compile the Autoencoder.
# Use binary_crossenropy as loss and metrics as accuracy.


autoencoder.compile(optimizer='SGD', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ___________________![image.png](attachment:c8684fc7-fcb0-48bf-87e8-f70857a0fc4e.png)

# %% [markdown]
# ____________________![image.png](attachment:30a3bc58-49bd-4849-8c76-e2551d3a033b.png)

# %%
history = autoencoder.fit(x_train, x_train, epochs=20, validation_data=(x_test, x_test))
# Out:
# Epoch 1/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.0697 - loss: 0.6900 - val_accuracy: 0.0789 - val_loss: 0.6863
# Epoch 2/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.0806 - loss: 0.6642 - val_accuracy: 0.0869 - val_loss: 0.5762
# Epoch 3/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.0983 - loss: 0.3455 - val_accuracy: 0.1039 - val_loss: 0.2775
# Epoch 4/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.1058 - loss: 0.2746 - val_accuracy: 0.1054 - val_loss: 0.2718
# Epoch 5/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.1053 - loss: 0.2711 - val_accuracy: 0.1046 - val_loss: 0.2695
# Epoch 6/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.1031 - loss: 0.2693 - val_accuracy: 0.0994 - val_loss: 0.2681
# Epoch 7/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.0897 - loss: 0.2680 - val_accuracy: 0.0729 - val_loss: 0.2672
# Epoch 8/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.0707 - loss: 0.2670 - val_accuracy: 0.0694 - val_loss: 0.2664
# Epoch 9/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.0697 - loss: 0.2663 - val_accuracy: 0.0689 - val_loss: 0.2658
# Epoch 10/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.0694 - loss: 0.2657 - val_accuracy: 0.0701 - val_loss: 0.2652
# Epoch 11/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.0694 - loss: 0.2651 - val_accuracy: 0.0692 - val_loss: 0.2646
# Epoch 12/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.0695 - loss: 0.2646 - val_accuracy: 0.0685 - val_loss: 0.2641
# Epoch 13/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.0692 - loss: 0.2641 - val_accuracy: 0.0718 - val_loss: 0.2636
# Epoch 14/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.0697 - loss: 0.2636 - val_accuracy: 0.0688 - val_loss: 0.2631
# Epoch 15/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.0698 - loss: 0.2631 - val_accuracy: 0.0694 - val_loss: 0.2626
# Epoch 16/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.0704 - loss: 0.2626 - val_accuracy: 0.0704 - val_loss: 0.2621
# Epoch 17/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.0712 - loss: 0.2620 - val_accuracy: 0.0715 - val_loss: 0.2615
# Epoch 18/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.0729 - loss: 0.2615 - val_accuracy: 0.0741 - val_loss: 0.2609
# Epoch 19/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.0750 - loss: 0.2609 - val_accuracy: 0.0741 - val_loss: 0.2603
# Epoch 20/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.0764 - loss: 0.2602 - val_accuracy: 0.0781 - val_loss: 0.2596

# %% [markdown]
# ___________________![image.png](attachment:b2f19fbc-57fa-40f7-80a1-336642829de1.png)

# %%
losses = history.history['loss']
val_losses = history.history['val_loss']
epochs = range(1, len(losses) + 1)

plt.figure(figsize=(15, 6))
plt.plot(epochs, losses, 'bo', label='Training loss')
plt.plot(epochs, val_losses, 'b', label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss function - binary_crossenttropy')
plt.legend()
plt.show()

# %% [markdown]
# _______________________![image.png](attachment:39f152ac-8692-403f-a1c4-3a71fe4fd978.png)

# %%
accuracy_array = history.history['accuracy']
val_accuracy_array = history.history['val_accuracy']
epochs = range(1, len(accuracy_array) + 1)
plt.figure(figsize=(15, 7))
plt.plot(epochs, accuracy_array, 'bo', label='Training accuracy')
plt.plot(epochs, val_accuracy_array, 'b', label='Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
decoded_images = autoencoder.predict(x_test)
n=10
plt.figure(figsize=(20, 4))
for i in range(n):
    ax = plt.subplot(2, n, i +1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_images[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# <html> <h3 style="font-style:italic; color:blue;"> AutoEncoders for Denoising Images : </h3> </html>
#
# Use the same digit data set. Add Gaussian noise to it to train an autoencoder that removes noise. Test the noisy samples.

# %% [markdown]
# ______________________![image.png](attachment:66c883c0-27ea-473a-bfbf-adf60d8af39f.png)

# %%
from tensorflow.keras.layers import GaussianNoise

# %%
#GaussianNoise?

# %% [markdown]
# ___________________![image.png](attachment:daef4479-63f7-4a6a-9927-be13f2230632.png)

# %%
sample = GaussianNoise(0.2)
noisey = sample(x_test[0:2],training=True)

# %%
# Plot the original and noisy images

# %% [markdown]
# _______________________![image.png](attachment:4013cb09-7c0a-4cc7-b208-31bda1d0f668.png)

# %%
x_test[0].size
# Out:
# 784

# %% [markdown]
# ____________________![image.png](attachment:2e2bac52-3120-4879-9117-f71bdf1ac965.png)

# %%
plt.imshow(x_test[0])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# _____________________![image.png](attachment:003958e0-35f7-4d32-8faf-b9486b5d206f.png)

# %%
plt.imshow(noisey[0])
plt.show()

# %% [markdown]
# _________![image.png](attachment:dd745f81-2f9e-4b45-b030-3a4529ea6f1d.png)

# %%
plt.imshow(x_test[1])
plt.show()

# %% [markdown]
# ______________________![image.png](attachment:cf4f913b-10d4-47b9-9d91-b22fd1c175fa.png)

# %%
plt.imshow(noisey[1])
plt.show()

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Create a noise removal autoencoder and train it </h4> </html>
#
# - Again similar to above it is a symmetric dense network.
# - Gaussian noise is added at the input so that the network sees noisy images and is able to map it to the clean outputs.

# %% [markdown]
# ### Input - Images with noise
# ### Labels - Clean images.

# %%
encoder = Sequential()
encoder.add(Flatten(input_shape=[28,28]))
encoder.add(GaussianNoise(0.2)) # We are adding noise to make input as noisy images

# Add layers of Encoder network. You could use the same number of layers as you created earlier
encoder.add(Dense(50, activation='relu'))
encoder.add(Dense(25, activation='relu'))

print(encoder.summary())
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_1 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gaussian_noise_1                │ (None, 784)            │             0 │
# │ (GaussianNoise)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 50)             │        39,250 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 25)             │         1,275 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 40,525 (158.30 KB)
#  Trainable params: 40,525 (158.30 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
# Your OWN Encoder model should be printed here
# Please do not copy the model below

# %%
decoder = Sequential()
decoder.add(Dense(50,input_shape=[25],activation='relu'))

# Add layers of the Decoder network. You could use the same number of layers as you created earlier
# Reember - Encoder and Decoder must be symmetric


decoder.add(Dense(28 * 28, activation="sigmoid"))
decoder.add(Reshape([28, 28]))

print(decoder.summary())
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_7 (Dense)                 │ (None, 50)             │         1,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 784)            │        39,984 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_1 (Reshape)             │ (None, 28, 28)         │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 41,284 (161.27 KB)
#  Trainable params: 41,284 (161.27 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
print(decoder.summary())
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_7 (Dense)                 │ (None, 50)             │         1,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 784)            │        39,984 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_1 (Reshape)             │ (None, 28, 28)         │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 41,284 (161.27 KB)
#  Trainable params: 41,284 (161.27 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# _________________________![image.png](attachment:b8742807-43dd-41a1-a461-c2a4455e6d07.png)

# %%
# Your code to print the Autoencoder model

#

# %%
noise_remover = Sequential([encoder, decoder])
print(noise_remover.summary())
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential_3 (Sequential)       │ (None, 25)             │        40,525 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_4 (Sequential)       │ (None, 28, 28)         │        41,284 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 81,809 (319.57 KB)
#  Trainable params: 81,809 (319.57 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
print(noise_remover.summary())
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential_3 (Sequential)       │ (None, 25)             │        40,525 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_4 (Sequential)       │ (None, 28, 28)         │        41,284 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 81,809 (319.57 KB)
#  Trainable params: 81,809 (319.57 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
# Your OWN Autoencoder model should be printed here

# %%
# Your code to compile the 'noise_remover' model with the same parameters as earlier

# noise_remover.compile( ................  )

noise_remover.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
# Your code to fit 'noise_remover' model with the same parameters as earlier

# history_2 = ..........................

history_2 = noise_remover.fit(x_train, x_train, epochs=20, validation_data=(x_test, x_test))
# Out:
# Epoch 1/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.1852 - loss: 0.1685 - val_accuracy: 0.2256 - val_loss: 0.1262
# Epoch 2/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.2355 - loss: 0.1240 - val_accuracy: 0.2433 - val_loss: 0.1126
# Epoch 3/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.2458 - loss: 0.1167 - val_accuracy: 0.2503 - val_loss: 0.1080
# Epoch 4/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.2510 - loss: 0.1134 - val_accuracy: 0.2588 - val_loss: 0.1051
# Epoch 5/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.2550 - loss: 0.1113 - val_accuracy: 0.2596 - val_loss: 0.1037
# Epoch 6/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.2570 - loss: 0.1101 - val_accuracy: 0.2605 - val_loss: 0.1030
# Epoch 7/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.2585 - loss: 0.1091 - val_accuracy: 0.2646 - val_loss: 0.1012
# Epoch 8/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.2604 - loss: 0.1077 - val_accuracy: 0.2661 - val_loss: 0.0997
# Epoch 9/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.2618 - loss: 0.1069 - val_accuracy: 0.2669 - val_loss: 0.0995
# Epoch 10/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.2620 - loss: 0.1064 - val_accuracy: 0.2650 - val_loss: 0.0988
# Epoch 11/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.2634 - loss: 0.1059 - val_accuracy: 0.2649 - val_loss: 0.0983
# Epoch 12/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.2634 - loss: 0.1055 - val_accuracy: 0.2654 - val_loss: 0.0981
# Epoch 13/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.2645 - loss: 0.1050 - val_accuracy: 0.2691 - val_loss: 0.0976
# Epoch 14/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.2650 - loss: 0.1047 - val_accuracy: 0.2705 - val_loss: 0.0974
# Epoch 15/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.2655 - loss: 0.1043 - val_accuracy: 0.2691 - val_loss: 0.0970
# Epoch 16/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.2657 - loss: 0.1041 - val_accuracy: 0.2748 - val_loss: 0.0968
# Epoch 17/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.2663 - loss: 0.1039 - val_accuracy: 0.2720 - val_loss: 0.0968
# Epoch 18/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.2668 - loss: 0.1037 - val_accuracy: 0.2711 - val_loss: 0.0967
# Epoch 19/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.2666 - loss: 0.1035 - val_accuracy: 0.2718 - val_loss: 0.0965
# Epoch 20/20
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.2671 - loss: 0.1033 - val_accuracy: 0.2717 - val_loss: 0.0962

# %%
# Hint: Use (copy and modify) the code from the cells above

# %% [markdown]
# ___________________![image.png](attachment:05682556-9ec1-46c6-85d5-3db97ba3c04f.png)

# %%
losses = history_2.history['loss']
losses_val = history_2.history['val_loss']
epochs = range(1, len(losses) + 1)

plt.figure(num=1, figsize=(15, 7))
plt.plot(epochs, losses, 'bo', label='Training loss')
plt.plot(epochs, losses_val, 'b', label='Validation loss')

plt.xlabel('Epochs')
plt.ylabel('Loss function - binary_crossentropy')
plt.legend()

plt.show()

# %% [markdown]
# ___________________________![image.png](attachment:43697532-dcb7-41bf-a1fa-6f630f5d4a29.png)

# %%
accuracy_array = history_2.history['accuracy']
val_accuracy_array = history_2.history['val_accuracy']
epochs = range(1, len(accuracy_array) + 1)
plt.figure(figsize=(15, 7))
plt.plot(epochs, accuracy_array, 'bo', label='Training accuracy')
plt.plot(epochs, val_accuracy_array, 'b', label='Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ______________________![image.png](attachment:9dbf1489-73d6-4480-adc7-0ced14e0c9dd.png)

# %%
hundred_noisey_images = sample(x_test[0:100],training=True)
denoised= noise_remover(hundred_noisey_images[0:100])

# %% [markdown]
# ______________________![image.png](attachment:a5bc2008-bc25-45e7-97ba-ae44dffae6ed.png)

# %%
import random

# %% [markdown]
# _______![image.png](attachment:505ed502-6fd8-4f58-a27f-44a804f20493.png)

# %%
import random

n = random.randint(0, 100)

print(n)

print("The Original")
plt.imshow(x_test[n])
plt.show()

print("The Noisey Version")
plt.imshow(hundred_noisey_images[n])
plt.show()

print("After going through denoiser")
plt.imshow(denoised[n])
plt.show()
# Out:
# 50
# The Original
# The Noisey Version
# After going through denoiser

# %% [markdown]
# <html> <h2 style="font-style:bold; color:red;"> Lab Logbook requirements </h2> </html>
#
#  - Put the Encoder, Decoder and Basic Autoencoder models using summary() in your lab logbook.
#
# Ensure that no code or other information is added to the logbook and that only required information is present. Marks will not be awarded if anything else is found in the logbook or instructions are not clearly followed.
#
# NOTE: DON'T FORGET TO SAVE AND BACK UP YOUR COMPLETED JUPYTER NOTEBOOK AND LAB LOGBOOK ON GITHUB OR ONEDRIVE.
